# %%
from google.colab import drive

drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
matplotlib.rcParams["figure.figsize"] = (20, 10)

# %%
main_path = "/content/gdrive/My Drive/Remote LSTM"

# %%
file_path = "LostCreek_MI_DailyData.xlsx"
df = pd.read_excel(f"{main_path}/Data Daily/{file_path}")
df = df.set_index("Date")
plt.plot(df)

# %%
file_path = "NE3_DailyData.xlsx"
df = pd.read_excel(f"{main_path}/Data Daily/{file_path}")
df = df.set_index("Date")
plt.plot(df)

# %%
file_path = "TonziRanch_CA_DailyData.xlsx"
df = pd.read_excel(f"{main_path}/Data Daily/{file_path}")
df = df.set_index("Date")
plt.plot(df)

# %%
file_path = "WalnutGulchWatershed_AZ_DailyData.xlsx"
df = pd.read_excel(f"{main_path}/Data Daily/{file_path}")
df = df.set_index("Date")
plt.plot(df)
